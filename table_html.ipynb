# %%
import pandas as pd

# %%
df = pd.read_csv("../Python-API/weatherdata.csv")
df.head()
# Out:
#          City   Wind  Temperature  Humidity  Cloudiness  Latitude
# 0  vila velha  10.29        80.60        74           0     -3.71
# 1       hobyo  19.48        76.72        82           0      5.35
# 2     ushuaia  17.22        41.00        60          90    -54.81
# 3      dikson  18.70        51.29        75          92     73.51
# 4    hermanus   3.60        35.59       100           8    -34.42

# %%
html_table = df.to_html()
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>City</th>      <th>Wind</th>      <th>Temperature</th>      <th>Humidity</th>      <th>Cloudiness</th>      <th>Latitude</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>vila velha</td>      <td>10.29</td>      <td>80.60</td>      <td>74</td>      <td>0</td>      <td>-3.71</td>    </tr>    <tr>      <th>1</th>      <td>hobyo</td>      <td>19.48</td>      <td>76.72</td>      <td>82</td>      <td>0</td>      <td>5.35</td>    </tr>    <tr>      <th>2</th>      <td>ushuaia</td>      <td>17.22</td>      <td>41.00</td>      <td>60</td>      <td>90</td>      <td>-54.81</td>    </tr>    <tr>      <th>3</th>      <td>dikson</td>      <td>18.70</td>      <td>51.29</td>      <td>75</td>      <td>92</td>      <td>73.51</td>    </tr>    <tr>      <th>4</th>      <td>hermanus</td>      <td>3.60</td>      <td>35.59</td>      <td>100</td>      <td>8</td>      <td>-34.42</td>    
# ...

# %%
df.to_html('table.html')
